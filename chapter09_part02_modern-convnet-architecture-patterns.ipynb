# %% [markdown]
# ### Residual connections

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Residual block where the number of filters changes

# %%
from tensorflow import keras
from tensorflow.keras import layers

inputs = keras.Input(shape=(32, 32, 3))
x = layers.Conv2D(32, 3, activation="relu")(inputs)
residual = x
x = layers.Conv2D(64, 3, activation="relu", padding="same")(x)
residual = layers.Conv2D(64, 1)(residual)
x = layers.add([x, residual])

# %% [markdown]
# #### Case where target block includes a max pooling layer

# %%
inputs = keras.Input(shape=(32, 32, 3))
x = layers.Conv2D(32, 3, activation="relu")(inputs)
residual = x
x = layers.Conv2D(64, 3, activation="relu", padding="same")(x)
x = layers.MaxPool2D(2, padding="same")(x)
residual = layers.Conv2D(64, 1, strides=2)(residual)
x = layers.add([x, residual])

# %% [markdown]
# ### Custom Residual Block Function with Optional Pooling

# %%
input = keras.Input(shape=(32, 32, 3))
x = layers.Rescaling(1.0 / 255)(input)

def residual_block(x, filters, pooling=False):
    residual = x
    x = layers.Conv2D(filters, 3, activation="relu", padding="same")(x)
    x = layers.Conv2D(filters, 3, activation="relu", padding="same")(x)
    if pooling:
        x = layers.MaxPool2D(3, strides=2, padding="same")(x)
        residual = layers.Conv2D(filters, 1, strides=2)(residual)
    elif filters != residual.shape[-1]:
        residual = layers.Conv2D(filters, 1)(residual)
    x = layers.add([x, residual])
    return x

x = residual_block(x, 32, pooling=True)
x = residual_block(x, 64, pooling=True)
x = residual_block(x, 128, pooling=False)

x = layers.GlobalAveragePooling2D()(x)
output = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(input, output)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 32, 32, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 32, 32, 3) │          0 │ input_layer_2[0]… │
# │ (Rescaling)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │        896 │ rescaling[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │      9,248 │ conv2d_6[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 16, 16,    │          0 │ conv2d_7[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 16, 16,    │        128 │ rescaling[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 16, 16,    │          0 │ max_pooling2d_1[… │
# │                     │ 32)               │            │ conv2d_8[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, 16,    │     18,496 │ add_2[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 16, 16,    │     36,928 │ conv2d_9[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 8, 8, 64)  │          0 │ conv2d_10[0][0]   │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 8, 8, 64)  │      2,112 │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 8, 8, 64)  │          0 │ max_pooling2d_2[… │
# │                     │                   │            │ conv2d_11[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 8, 8, 128) │     73,856 │ add_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 8, 8, 128) │    147,584 │ conv2d_12[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 8, 8, 128) │      8,320 │ add_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 8, 8, 128) │          0 │ conv2d_13[0][0],  │
# │                     │                   │            │ conv2d_14[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ add_4[0][0]       │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 1)         │        129 │ global_average_p… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 297,697 (1.14 MB)
#  Trainable params: 297,697 (1.14 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Putting it together: A mini Xception-like model

# %%
import os, shutil, pathlib
from tensorflow.keras.utils import image_dataset_from_directory

original_dir = pathlib.Path("/home/ziad/Projects/dogs-vs-cats/train/train")
new_base_dir = pathlib.Path("/home/ziad/Projects/dogs-vs-cats/cats_vs_dogs_small")

# def make_subset(subset_name, start_index, end_index):
#     for category in ("cat", "dog"):
#         dir = new_base_dir / subset_name / category
#         os.makedirs(dir)
#         fnames = [f"{category}.{i}.jpg" for i in range(start_index, end_index)]
#         for fname in fnames:
#             shutil.copyfile(src=original_dir / fname,
#                             dst=dir / fname)

# make_subset("train", start_index=0, end_index=1000)
# make_subset("validation", start_index=1000, end_index=1500)
# make_subset("test", start_index=1500, end_index=2500)

train_dataset = image_dataset_from_directory(
    new_base_dir / "train",
    image_size=(180, 180),
    batch_size=32)
validation_dataset = image_dataset_from_directory(
    new_base_dir / "validation",
    image_size=(180, 180),
    batch_size=32)
test_dataset = image_dataset_from_directory(
    new_base_dir / "test",
    image_size=(180, 180),
    batch_size=32)
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.

# %% [markdown]
# ### Model Definition with Data Augmentation

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
    ]
)

# %%
input = keras.Input(shape=(180, 180, 3))
x = data_augmentation(input)

# Residual Convolutional Layers
x = layers.Rescaling(1.0 / 255)(x)
x = layers.Conv2D(32, 5, use_bias=False)(x)

for size in [32, 64, 128, 256, 512]:
    residual = x

    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.SeparableConv2D(size, 3, padding="same", use_bias=False)(x)

    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.SeparableConv2D(size, 3, padding="same", use_bias=False)(x)

    x = layers.MaxPool2D(3, strides=2, padding="same")(x)

    residual = layers.Conv2D(size, 1, strides=2, padding="same", use_bias=False)(residual)
    x = layers.add([x, residual])

x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.5)(x)
output = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(input, output)
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 180, 180,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential          │ (None, 180, 180,  │          0 │ input_layer_3[0]… │
# │ (Sequential)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_1         │ (None, 180, 180,  │          0 │ sequential[0][0]  │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 176, 176,  │      2,400 │ rescaling_1[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 176, 176,  │        128 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 176, 176,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d    │ (None, 176, 176,  │      1,312 │ activation[0][0]  │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 176, 176,  │        128 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 176, 176,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_1  │ (None, 176, 176,  │      1,312 │ activation_1[0][… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 88, 88,    │          0 │ separable_conv2d… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 88, 88,    │      1,024 │ conv2d_15[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 88, 88,    │          0 │ max_pooling2d_3[… │
# │                     │ 32)               │            │ conv2d_16[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 88, 88,    │        128 │ add_5[0][0]       │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 88, 88,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_2  │ (None, 88, 88,    │      2,336 │ activation_2[0][… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 88, 88,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 88, 88,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_3  │ (None, 88, 88,    │      4,672 │ activation_3[0][… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 44, 44,    │          0 │ separable_conv2d… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 44, 44,    │      2,048 │ add_5[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 44, 44,    │          0 │ max_pooling2d_4[… │
# │                     │ 64)               │            │ conv2d_17[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 44, 44,    │        256 │ add_6[0][0]       │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 44, 44,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_4  │ (None, 44, 44,    │      8,768 │ activation_4[0][… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 44, 44,    │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 44, 44,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_5  │ (None, 44, 44,    │     17,536 │ activation_5[0][… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_5     │ (None, 22, 22,    │          0 │ separable_conv2d… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 22, 22,    │      8,192 │ add_6[0][0]       │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 22, 22,    │          0 │ max_pooling2d_5[… │
# │                     │ 128)              │            │ conv2d_18[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 22, 22,    │        512 │ add_7[0][0]       │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 22, 22,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_6  │ (None, 22, 22,    │     33,920 │ activation_6[0][… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 22, 22,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 22, 22,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_7  │ (None, 22, 22,    │     67,840 │ activation_7[0][… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 11, 11,    │          0 │ separable_conv2d… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 11, 11,    │     32,768 │ add_7[0][0]       │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 11, 11,    │          0 │ max_pooling2d_6[… │
# │                     │ 256)              │            │ conv2d_19[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 11, 11,    │      1,024 │ add_8[0][0]       │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 11, 11,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_8  │ (None, 11, 11,    │    133,376 │ activation_8[0][… │
# │ (SeparableConv2D)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 11, 11,    │      2,048 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 11, 11,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_9  │ (None, 11, 11,    │    266,752 │ activation_9[0][… │
# │ (SeparableConv2D)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, 6, 6, 512) │          0 │ separable_conv2d… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 6, 6, 512) │    131,072 │ add_8[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 6, 6, 512) │          0 │ max_pooling2d_7[… │
# │                     │                   │            │ conv2d_20[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ add_9[0][0]       │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 512)       │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │        513 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 721,857 (2.75 MB)
#  Trainable params: 718,849 (2.74 MB)
#  Non-trainable params: 3,008 (11.75 KB)

# %%
model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
history = model.fit(train_dataset, epochs=100, validation_data=validation_dataset)
# Out:
# Epoch 1/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 15s 159ms/step - accuracy: 0.8292 - loss: 0.3888 - val_accuracy: 0.7980 - val_loss: 0.4435
# Epoch 2/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 156ms/step - accuracy: 0.8527 - loss: 0.3333 - val_accuracy: 0.7550 - val_loss: 0.4902
# Epoch 3/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 156ms/step - accuracy: 0.8356 - loss: 0.3521 - val_accuracy: 0.7110 - val_loss: 0.5842
# Epoch 4/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 154ms/step - accuracy: 0.8576 - loss: 0.3358 - val_accuracy: 0.7430 - val_loss: 0.6103
# Epoch 5/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 155ms/step - accuracy: 0.8474 - loss: 0.3423 - val_accuracy: 0.7490 - val_loss: 0.7077
# Epoch 6/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 156ms/step - accuracy: 0.8586 - loss: 0.3271 - val_accuracy: 0.8150 - val_loss: 0.3857
# Epoch 7/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 154ms/step - accuracy: 0.8571 - loss: 0.3318 - val_accuracy: 0.6890 - val_loss: 0.7122
# Epoch 8/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 154ms/step - accuracy: 0.8727 - loss: 0.2983 - val_accuracy: 0.7550 - val_loss: 0.6697
# Epoch 9/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 153ms/step - accuracy: 0.8727 - loss: 0.3165 - val_accuracy: 0.7120 - val_loss: 0.7755
# Epoch 10/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 154ms/step - accuracy: 0.8680 - loss: 0.3019 - val_accuracy: 0.7990 - val_loss: 0.5482
# Epoch 11/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 154ms/step - accuracy: 0.8557 - loss: 0.3196 - val_accuracy: 0.8330 - val_loss: 0.3587
# Epoch 12/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 154ms/step - accuracy: 0.8869 - loss: 0.2883 - val_accuracy: 0.8390 - val_loss: 0.4118
# Epoch 13/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 155ms/step - accuracy: 0.8748 - loss: 0.2994 - val_accuracy: 0.7450 - val_loss: 0.7309
# Epoch 14/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 156ms/step - accuracy: 0.8852 - loss: 0.2761 - val_accuracy: 0.6930 - val_loss: 1.1831
# Epoch 15/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.8790 - loss: 0.2819 - val_accuracy: 0.8360 - val_loss: 0.4209
# Epoch 16/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.8954 - loss: 0.2526 - val_accuracy: 0.6410 - val_loss: 1.3656
# Epoch 17/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 156ms/step - accuracy: 0.9041 - loss: 0.2309 - val_accuracy: 0.6730 - val_loss: 1.7007
# Epoch 18/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 163ms/step - accuracy: 0.8956 - loss: 0.2570 - val_accuracy: 0.8320 - val_loss: 0.3816
# Epoch 19/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 165ms/step - accuracy: 0.8977 - loss: 0.2441 - val_accuracy: 0.6970 - val_loss: 1.1440
# Epoch 20/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 165ms/step - accuracy: 0.8988 - loss: 0.2589 - val_accuracy: 0.8480 - val_loss: 0.3704
# Epoch 21/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 164ms/step - accuracy: 0.9067 - loss: 0.2293 - val_accuracy: 0.8460 - val_loss: 0.4336
# Epoch 22/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.9155 - loss: 0.2036 - val_accuracy: 0.7900 - val_loss: 0.4760
# Epoch 23/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 163ms/step - accuracy: 0.8965 - loss: 0.2386 - val_accuracy: 0.8270 - val_loss: 0.4613
# Epoch 24/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 164ms/step - accuracy: 0.9036 - loss: 0.2376 - val_accuracy: 0.7750 - val_loss: 0.6210
# Epoch 25/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.9263 - loss: 0.1975 - val_accuracy: 0.7660 - val_loss: 0.7804
# Epoch 26/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 159ms/step - accuracy: 0.9150 - loss: 0.1923 - val_accuracy: 0.8600 - val_loss: 0.3513
# Epoch 27/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 160ms/step - accuracy: 0.9214 - loss: 0.1896 - val_accuracy: 0.8510 - val_loss: 0.3692
# Epoch 28/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 161ms/step - accuracy: 0.9240 - loss: 0.1908 - val_accuracy: 0.8350 - val_loss: 0.5403
# Epoch 29/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 155ms/step - accuracy: 0.9171 - loss: 0.1938 - val_accuracy: 0.8410 - val_loss: 0.5150
# Epoch 30/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 155ms/step - accuracy: 0.9270 - loss: 0.1934 - val_accuracy: 0.8580 - val_loss: 0.3583
# Epoch 31/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 155ms/step - accuracy: 0.9211 - loss: 0.1847 - val_accuracy: 0.8260 - val_loss: 0.5193
# Epoch 32/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 156ms/step - accuracy: 0.9262 - loss: 0.1835 - val_accuracy: 0.8630 - val_loss: 0.3408
# Epoch 33/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 159ms/step - accuracy: 0.9096 - loss: 0.2143 - val_accuracy: 0.8750 - val_loss: 0.2994
# Epoch 34/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 159ms/step - accuracy: 0.9308 - loss: 0.1721 - val_accuracy: 0.8690 - val_loss: 0.3311
# Epoch 35/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 156ms/step - accuracy: 0.9268 - loss: 0.1921 - val_accuracy: 0.8820 - val_loss: 0.3048
# Epoch 36/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.9344 - loss: 0.1686 - val_accuracy: 0.8420 - val_loss: 0.3957
# Epoch 37/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.9289 - loss: 0.1758 - val_accuracy: 0.8440 - val_loss: 0.4847
# Epoch 38/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 160ms/step - accuracy: 0.9228 - loss: 0.1733 - val_accuracy: 0.8270 - val_loss: 0.4392
# Epoch 39/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 156ms/step - accuracy: 0.9380 - loss: 0.1423 - val_accuracy: 0.8430 - val_loss: 0.4794
# Epoch 40/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 160ms/step - accuracy: 0.9309 - loss: 0.1617 - val_accuracy: 0.7650 - val_loss: 0.7166
# Epoch 41/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.9426 - loss: 0.1450 - val_accuracy: 0.8310 - val_loss: 0.6843
# Epoch 42/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.9299 - loss: 0.1787 - val_accuracy: 0.8020 - val_loss: 0.5900
# Epoch 43/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 159ms/step - accuracy: 0.9442 - loss: 0.1515 - val_accuracy: 0.8500 - val_loss: 0.3380
# Epoch 44/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 159ms/step - accuracy: 0.9426 - loss: 0.1445 - val_accuracy: 0.8400 - val_loss: 0.5065
# Epoch 45/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.9418 - loss: 0.1460 - val_accuracy: 0.8340 - val_loss: 0.4563
# Epoch 46/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.9314 - loss: 0.1689 - val_accuracy: 0.8370 - val_loss: 0.5056
# Epoch 47/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.9358 - loss: 0.1431 - val_accuracy: 0.8610 - val_loss: 0.4703
# Epoch 48/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.9496 - loss: 0.1175 - val_accuracy: 0.8180 - val_loss: 0.6061
# Epoch 49/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.9521 - loss: 0.1182 - val_accuracy: 0.8650 - val_loss: 0.3929
# Epoch 50/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 160ms/step - accuracy: 0.9355 - loss: 0.1402 - val_accuracy: 0.8230 - val_loss: 0.5144
# Epoch 51/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.9459 - loss: 0.1518 - val_accuracy: 0.8740 - val_loss: 0.2891
# Epoch 52/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 159ms/step - accuracy: 0.9470 - loss: 0.1193 - val_accuracy: 0.8890 - val_loss: 0.3309
# Epoch 53/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 163ms/step - accuracy: 0.9372 - loss: 0.1549 - val_accuracy: 0.8790 - val_loss: 0.4466
# Epoch 54/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 164ms/step - accuracy: 0.9481 - loss: 0.1183 - val_accuracy: 0.8590 - val_loss: 0.4536
# Epoch 55/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 161ms/step - accuracy: 0.9541 - loss: 0.1127 - val_accuracy: 0.8740 - val_loss: 0.3775
# Epoch 56/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.9546 - loss: 0.1069 - val_accuracy: 0.8790 - val_loss: 0.4413
# Epoch 57/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 156ms/step - accuracy: 0.9333 - loss: 0.1577 - val_accuracy: 0.7750 - val_loss: 0.8585
# Epoch 58/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.9487 - loss: 0.1242 - val_accuracy: 0.9040 - val_loss: 0.2934
# Epoch 59/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.9486 - loss: 0.1199 - val_accuracy: 0.8980 - val_loss: 0.2759
# Epoch 60/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.9422 - loss: 0.1278 - val_accuracy: 0.8810 - val_loss: 0.3209
# Epoch 61/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 156ms/step - accuracy: 0.9482 - loss: 0.1304 - val_accuracy: 0.8810 - val_loss: 0.3588
# Epoch 62/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 155ms/step - accuracy: 0.9566 - loss: 0.1067 - val_accuracy: 0.8540 - val_loss: 0.5014
# Epoch 63/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 155ms/step - accuracy: 0.9524 - loss: 0.1205 - val_accuracy: 0.8670 - val_loss: 0.4727
# Epoch 64/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 155ms/step - accuracy: 0.9395 - loss: 0.1396 - val_accuracy: 0.8710 - val_loss: 0.4742
# Epoch 65/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 155ms/step - accuracy: 0.9640 - loss: 0.0917 - val_accuracy: 0.8130 - val_loss: 0.7376
# Epoch 66/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 156ms/step - accuracy: 0.9588 - loss: 0.1176 - val_accuracy: 0.8710 - val_loss: 0.3724
# Epoch 67/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 156ms/step - accuracy: 0.9498 - loss: 0.1254 - val_accuracy: 0.8910 - val_loss: 0.2990
# Epoch 68/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.9559 - loss: 0.1192 - val_accuracy: 0.8720 - val_loss: 0.3668
# Epoch 69/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 155ms/step - accuracy: 0.9603 - loss: 0.1005 - val_accuracy: 0.8630 - val_loss: 0.4919
# Epoch 70/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 156ms/step - accuracy: 0.9582 - loss: 0.0979 - val_accuracy: 0.9030 - val_loss: 0.2927
# Epoch 71/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 156ms/step - accuracy: 0.9618 - loss: 0.1064 - val_accuracy: 0.8130 - val_loss: 0.5881
# Epoch 72/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 156ms/step - accuracy: 0.9636 - loss: 0.1046 - val_accuracy: 0.8890 - val_loss: 0.4602
# Epoch 73/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 155ms/step - accuracy: 0.9676 - loss: 0.0748 - val_accuracy: 0.9140 - val_loss: 0.3053
# Epoch 74/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 156ms/step - accuracy: 0.9615 - loss: 0.1205 - val_accuracy: 0.8870 - val_loss: 0.3305
# Epoch 75/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 156ms/step - accuracy: 0.9592 - loss: 0.1128 - val_accuracy: 0.8880 - val_loss: 0.3367
# Epoch 76/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 156ms/step - accuracy: 0.9614 - loss: 0.0987 - val_accuracy: 0.8840 - val_loss: 0.3558
# Epoch 77/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 156ms/step - accuracy: 0.9650 - loss: 0.0920 - val_accuracy: 0.8380 - val_loss: 0.5684
# Epoch 78/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 155ms/step - accuracy: 0.9704 - loss: 0.0769 - val_accuracy: 0.8780 - val_loss: 0.3546
# Epoch 79/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 155ms/step - accuracy: 0.9657 - loss: 0.1062 - val_accuracy: 0.8880 - val_loss: 0.3509
# Epoch 80/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 155ms/step - accuracy: 0.9698 - loss: 0.0708 - val_accuracy: 0.8680 - val_loss: 0.5038
# Epoch 81/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 155ms/step - accuracy: 0.9433 - loss: 0.1229 - val_accuracy: 0.8570 - val_loss: 0.4280
# Epoch 82/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 155ms/step - accuracy: 0.9701 - loss: 0.0897 - val_accuracy: 0.8210 - val_loss: 0.6511
# Epoch 83/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.9607 - loss: 0.1060 - val_accuracy: 0.8860 - val_loss: 0.3156
# Epoch 84/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 160ms/step - accuracy: 0.9621 - loss: 0.0975 - val_accuracy: 0.8790 - val_loss: 0.3922
# Epoch 85/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 159ms/step - accuracy: 0.9687 - loss: 0.0720 - val_accuracy: 0.9020 - val_loss: 0.3384
# Epoch 86/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.9734 - loss: 0.0823 - val_accuracy: 0.8410 - val_loss: 0.6141
# Epoch 87/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 156ms/step - accuracy: 0.9707 - loss: 0.0742 - val_accuracy: 0.8950 - val_loss: 0.3325
# Epoch 88/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 156ms/step - accuracy: 0.9628 - loss: 0.1071 - val_accuracy: 0.8930 - val_loss: 0.3646
# Epoch 89/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 155ms/step - accuracy: 0.9724 - loss: 0.0743 - val_accuracy: 0.8950 - val_loss: 0.3615
# Epoch 90/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 160ms/step - accuracy: 0.9681 - loss: 0.0762 - val_accuracy: 0.8870 - val_loss: 0.3665
# Epoch 91/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 156ms/step - accuracy: 0.9759 - loss: 0.0634 - val_accuracy: 0.8910 - val_loss: 0.3934
# Epoch 92/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.9570 - loss: 0.1204 - val_accuracy: 0.8830 - val_loss: 0.4792
# Epoch 93/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.9541 - loss: 0.1197 - val_accuracy: 0.8900 - val_loss: 0.3394
# Epoch 94/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 155ms/step - accuracy: 0.9669 - loss: 0.0950 - val_accuracy: 0.8760 - val_loss: 0.3309
# Epoch 95/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 156ms/step - accuracy: 0.9672 - loss: 0.0754 - val_accuracy: 0.8890 - val_loss: 0.3781
# Epoch 96/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.9633 - loss: 0.0860 - val_accuracy: 0.8830 - val_loss: 0.3668
# Epoch 97/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.9744 - loss: 0.0843 - val_accuracy: 0.8630 - val_loss: 0.4229
# Epoch 98/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 163ms/step - accuracy: 0.9658 - loss: 0.0783 - val_accuracy: 0.8860 - val_loss: 0.5049
# Epoch 99/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 164ms/step - accuracy: 0.9693 - loss: 0.0934 - val_accuracy: 0.8790 - val_loss: 0.3982
# Epoch 100/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 164ms/step - accuracy: 0.9592 - loss: 0.0899 - val_accuracy: 0.8880 - val_loss: 0.4525

# %%
import matplotlib.pyplot as plt
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]

epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.show()

# %%
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
# test the model
test_loss, test_accuracy = model.evaluate(test_dataset)
print(f"Test accuracy: {test_accuracy}")
print(f"Test loss: {test_loss}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.8693 - loss: 0.5073
# Test accuracy: 0.871999979019165
# Test loss: 0.5203524231910706
